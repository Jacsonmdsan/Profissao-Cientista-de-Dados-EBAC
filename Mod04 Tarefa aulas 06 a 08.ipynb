# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
# 1) Repita os mesmos passos feitos em aula, 
#    mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
pvds_rj = requests.get(url).json()
df_pvds_rj = pd.DataFrame(data['items'])
df_pvds_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      65267        Município  Miguel Pereira   3302908  RJ
# 1      58189        Município   Nova Friburgo   3303401  RJ
# 2      11005        Município        Araruama   3300209  RJ
# 3      13780        Município   Nova Friburgo   3303401  RJ
# 4       5618        Município     Nova Iguaçu   3303500  RJ
#
#                 num_pvl                                   status  \
# 0  PVL02.002355/2023-18                        Deferido (PVL-IF)
# 1  PVL02.003661/2022-91  Assinado pelo interessado (retificação)
# 2                  None           Arquivado por decurso de prazo
# 3                  None                                 Deferido
# 4                  None                                Arquivado
#
#            num_processo        data_protocolo  \
# 0                  None                  None
# 1  17944.101850/2022-91  2024-07-24T20:29:41Z
# 2  17944.001334/2011-12  2012-12-21T02:00:00Z
# 3  19405.000082/2002-38  2002-11-25T02:00:00Z
# 4  17944.000156/2010-13  2010-12-03T02:00:00Z
#
#                                        tipo_operacao  \
# 0                        Operação contratual interna
# 1  Operação contratual interna (com garantia da U...
# 2                        Operação contratual interna
# 3                        Operação contratual interna
# 4                        Operação contratual interna
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1                                     Infraestrutura
# 2  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 3                                               PMAT
# 4                          PAC - Saneamento - 2009 A
#
#                        tipo_credor  \
# 0  Instituição Financeira Nacional
# 1  Instituição Financeira Nacional
# 2  Instituição Financeira Nacional
# 3  Instituição Financeira Nacional
# 4  Instituição Financeira Nacional
#
#                                               credor moeda        valor  \
# 0                            Caixa Econômica Federal  Real  10000000.00
# 1                            Caixa Econômica Federal  Real  30000000.00
# 2                            Caixa Econômica Federal  Real  33593206.91
# 3  Banco Nacional de Desenvolvimento Econômico e ...  Real   2286000.00
# 4                            Caixa Econômica Federal  Real  60737300.00
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      1  13/07/2023
# 1                 0                      0  12/08/2024
# 2                 0                      0  09/01/2013
# 3                 1                      0  18/12/2002
# 4                 0                      0  15/12/2010

# %%
df_pvls_rj['uf'].value_counts()
# Out:
# uf
# RJ    268
# Name: count, dtype: int64

# %%
# 2) Seu código aqui
status_counts = df_pvls_rj['status'].value_counts()
top_status = status_counts.head(3)
print(f'Conforme a base de dados, as três maiores frequencias são os {top_status}')
# Out:
# Conforme a base de dados, as três maiores frequencias são os status
# Deferido        106
# Arquivado        53
# Regularizado     26
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df_pvls_rj['ano'] = df_pvls_rj['data_status'].str.slice(-4,None)

# %%
df_pvls_rj['ano'].value_counts().sort_index(ascending=True)
# Out:
# ano
# 2002     4
# 2003     1
# 2004     1
# 2006     4
# 2007    29
# 2008    37
# 2009     9
# 2010    19
# 2011    10
# 2012    13
# 2013    15
# 2014    20
# 2015     8
# 2016     4
# 2017     5
# 2018     4
# 2019    16
# 2020    15
# 2021     5
# 2022    11
# 2023    28
# 2024    10
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consultar_PVL(uf:str='SP', tipo_interessado:str='Estado') -> pd.DataFrame:
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={}&tipo_interessado={}'.format(
        uf, 
        tipo_interessado)
    r_uf = requests.get(url)  
    return pd.DataFrame(r_uf.json()['items'])

consultar_PVL('RJ', 'Município')
# Out:
#      id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0        65267        Município       Miguel Pereira   3302908  RJ
# 1        58189        Município        Nova Friburgo   3303401  RJ
# 2        11005        Município             Araruama   3300209  RJ
# 3        13780        Município        Nova Friburgo   3303401  RJ
# 4         5618        Município          Nova Iguaçu   3303500  RJ
# ..         ...              ...                  ...       ...  ..
# 263      62211        Município              Valença   3306107  RJ
# 264       8684        Município       Rio de Janeiro   3304557  RJ
# 265      11315        Município               Maricá   3302700  RJ
# 266      10226        Município  Conceição de Macabu   3301405  RJ
# 267       8820        Município         Belford Roxo   3300456  RJ
#
#                   num_pvl                                   status  \
# 0    PVL02.002355/2023-18                        Deferido (PVL-IF)
# 1    PVL02.003661/2022-91  Assinado pelo interessado (retificação)
# 2                    None           Arquivado por decurso de prazo
# 3                    None                                 Deferido
# 4                    None                                Arquivado
# ..                    ...                                      ...
# 263  PVL02.008444/2022-97                        Deferido (PVL-IF)
# 264                  None                                 Deferido
# 265                  None                                 Deferido
# 266                  None                                Arquivado
# 267                  None                                Arquivado
#
#              num_processo        data_protocolo  \
# 0                    None                  None
# 1    17944.101850/2022-91  2024-07-24T20:29:41Z
# 2    17944.001334/2011-12  2012-12-21T02:00:00Z
# 3    19405.000082/2002-38  2002-11-25T02:00:00Z
# 4    17944.000156/2010-13  2010-12-03T02:00:00Z
# ..                    ...                   ...
# 263                  None                  None
# 264  17944.000824/2011-93  2011-11-16T02:00:00Z
# 265  17944.001410/2010-09  2011-01-10T02:00:00Z
# 266  17944.001149/2008-14  2008-08-14T03:00:00Z
# 267  17944.000847/2008-01  2008-08-15T03:00:00Z
#
#                                          tipo_operacao  \
# 0                          Operação contratual interna
# 1    Operação contratual interna (com garantia da U...
# 2                          Operação contratual interna
# 3                          Operação contratual interna
# 4                          Operação contratual interna
# ..                                                 ...
# 263                        Operação contratual interna
# 264                        Operação contratual interna
# 265                        Operação contratual interna
# 266                        Operação contratual interna
# 267                        Operação contratual interna
#
#                                             finalidade  \
# 0                                       Infraestrutura
# 1                                       Infraestrutura
# 2    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 3                                                 PMAT
# 4                            PAC - Saneamento - 2009 A
# ..                                                 ...
# 263     Aquisição de máquinas, equipamentos e veículos
# 264                                  Saneamento básico
# 265                                               PMAT
# 266                                Caminho da Escola 2
# 267                          PAC - Saneamento - 2008 B
#
#                          tipo_credor  \
# 0    Instituição Financeira Nacional
# 1    Instituição Financeira Nacional
# 2    Instituição Financeira Nacional
# 3    Instituição Financeira Nacional
# 4    Instituição Financeira Nacional
# ..                               ...
# 263  Instituição Financeira Nacional
# 264  Instituição Financeira Nacional
# 265  Instituição Financeira Nacional
# 266  Instituição Financeira Nacional
# 267  Instituição Financeira Nacional
#
#                                                 credor moeda         valor  \
# 0                              Caixa Econômica Federal  Real  1.000000e+07
# 1                              Caixa Econômica Federal  Real  3.000000e+07
# 2                              Caixa Econômica Federal  Real  3.359321e+07
# 3    Banco Nacional de Desenvolvimento Econômico e ...  Real  2.286000e+06
# 4                              Caixa Econômica Federal  Real  6.073730e+07
# ..                                                 ...   ...           ...
# 263                                Banco do Brasil S/A  Real  7.148000e+06
# 264                            Caixa Econômica Federal  Real  1.432000e+08
# 265  Banco Nacional de Desenvolvimento Econômico e ...  Real  1.051389e+07
# 266                                Banco do Brasil S/A  Real  4.007000e+05
# 267                            Caixa Econômica Federal  Real  2.185000e+07
#
#      pvl_assoc_divida  pvl_contradado_credor data_status
# 0                   0                      1  13/07/2023
# 1                   0                      0  12/08/2024
# 2                   0                      0  09/01/2013
# 3                   1                      0  18/12/2002
# 4                   0                      0  15/12/2010
# ..                ...                    ...         ...
# 263                 0                      1  29/06/2023
# 264                 1                      0  03/01/2012
# 265                 1                      0  19/01/2011
# 266                 0                      0  30/10/2008
# 267                 0                      0  30/10/2008
#
# [268 rows x 18 columns]

# %%
# 2) Seu código aqui
df_estado_mg = consultar_PVL('MG', 'Estado')
print("Quantidade de solicitações para Minas Gerais com status em 'Arquivado por decurso de prazo':")
print(df_estado_mg[df_estado_mg['status'] == 'Arquivado por decurso de prazo'].shape[0])
# Out:
# Quantidade de solicitações para Minas Gerais com status em 'Arquivado por decurso de prazo':
# 1

# %%
# 3) Seu código aqui
df_estado_ba = consultar_PVL('BA', 'Município')
municipio_mais_solicitacoes = df_estado_ba['interessado'].value_counts().idxmax()
numero_solicitacoes = df_estado_ba['interessado'].value_counts().iloc[0]
print(f'O município da Bahia com mais solicitações deferidas: {municipio_mais_solicitacoes.upper()} com {numero_solicitacoes} solicitações deferidas.')
# Out:
# O município da Bahia com mais solicitações deferidas: CAMAÇARI com 21 solicitações deferidas.

# %%
# 4) Seu código aqui
df_pvls_estado_ba = consultar_PVL('BA', 'Estado')
df_pvls_estado_ba.to_csv('pvls_estado_ba.csv', index=False)
